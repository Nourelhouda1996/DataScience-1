# %% [markdown]
# <a href="https://colab.research.google.com/github/Nourelhouda1996/DataScience-1/blob/main/Sales_predictions_Machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

filename='/content/sales_predictions_2023.csv'
df=pd.read_csv(filename)
df = df.set_index("Item_Identifier")
df.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                  9.300          Low Fat         0.016047
# DRC01                  5.920          Regular         0.019278
# FDN15                 17.500          Low Fat         0.016760
# FDX07                 19.200          Regular         0.000000
# NCD19                  8.930          Low Fat         0.000000
# ...                      ...              ...              ...
# FDF22                  6.865          Low Fat         0.056783
# FDS36                  8.380          Regular         0.046982
# NCJ29                 10.600          Low Fat         0.035186
# FDN46                  7.210          Regular         0.145221
# DRG01                 14.800          Low Fat         0.044878
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# ...

# %%
df.isna().sum()
# Out:
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
y=df["Item_Outlet_Sales"]
X=df.drop(columns="Item_Outlet_Sales")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  \
# Item_Identifier
# NCG06                 16.350          Low Fat         0.029565     Household
# FDV57                 15.250          Regular         0.000000   Snack Foods
# FDM27                 12.350          Regular         0.158716          Meat
# FDG24                  7.975          Low Fat         0.014628  Baking Goods
# FDD05                 19.350          Low Fat         0.016645  Frozen Foods
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# NCG06            256.4646            OUT018                       2009
# FDV57            179.7660            OUT018                       2009
# FDM27            157.2946            OUT049                       1999
# FDG24             82.3250            OUT035                       2004
# FDD05            120.9098            OUT045                       2002
#
# ...

# %%
X_test.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDI28                 14.300          Low Fat         0.026300
# NCM17                  7.930          Low Fat         0.071136
# FDC14                 14.500          Regular         0.041313
# DRC36                    NaN          Regular         0.044767
# FDS27                 10.195          Regular         0.012456
#
#                           Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDI28                  Frozen Foods   79.4302            OUT013
# NCM17            Health and Hygiene   42.7086            OUT046
# FDC14                        Canned   42.0454            OUT049
# DRC36                   Soft Drinks  173.7054            OUT027
# FDS27                          Meat  197.5110            OUT035
#
#                  Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# ...

# %%
len(X_train)/len(X)*100
# Out:
# 74.99706676053033

# %%
len(X_test)/len(X)*100
# Out:
# 25.00293323946967

# %%
from sklearn.impute import SimpleImputer

# %%
num_cols = X_train.select_dtypes("number").columns

impute_mean = SimpleImputer(strategy='mean')

impute_mean.fit(X_train[num_cols])

X_train_num_imputed = impute_mean.transform(X_train[num_cols])

X_test_num_imputed = impute_mean.transform(X_test[num_cols])

# %%
cat_cols = X_train.select_dtypes("object").columns

impute_na = SimpleImputer(strategy='constant', fill_value='NA')

impute_na.fit(X_train[cat_cols])

X_train_cat_imputed = impute_na.transform(X_train[cat_cols])

X_test_cat_imputed = impute_na.transform(X_test[cat_cols])
